# %%
import numpy as np
import pandas as pd

df = pd.read_csv(
    "e_commerce.csv",
    dtype={
        "order_id": np.int16,
        "quantity": np.int8,
        "shipping_days": np.int8,
    },
    true_values=['Yes'],
    false_values=['No'],
    index_col=0,
)
df['order_date'] = pd.to_datetime(df['order_date'])
df.head()
# Out:
#          customer_id order_date product_category         product_name  \
# order_id
# 1001          CU-201 2020-01-15      Electronics  Wireless Headphones
# 1002          CU-156 2020-01-16         Clothing          Men's Jeans
# 1003          CU-342 2020-01-18   Home & Kitchen              Blender
# 1004          CU-201 2020-02-02      Electronics           Smartphone
# 1005          CU-499 2020-02-05            Books   Python Programming
#
#           quantity  unit_price  discount_pct payment_method    country  \
# order_id
# 1001             1       89.99          0.05    Credit Card        USA
# 1002             2       45.50          0.15         PayPal         UK
# 1003             1       32.75          0.00     Debit Card     Canada
# 1004             1      699.00          0.10    Credit Card        USA
# 1005             3       24.99          0.20         PayPal  Australia
#
#               city  shipping_days customer_segment  return_status
# order_id
# ...

# %%
df.loc[df["return_status"]==True,["product_name"]]
# Out:
#                  product_name
# order_id
# 1002              Men's Jeans
# 1007                Air Fryer
# 1012                    Mixer
# 1019              Men's Shirt
# 1027             Men's Shorts
# 1035      External Hard Drive
# 1044            Women's Skirt

# %%
unit_price_after_discount = np.round(df['unit_price'] * (1 - df['discount_pct']), 2)

df.insert(7, "unit_price_after_discount", unit_price_after_discount)
df.insert(8, "total_price_after_discount", unit_price_after_discount * df['quantity'])

# %%
df.insert(6, "total_price", df['unit_price'] * df['quantity'])

# %%
df.head()
# Out:
#          customer_id order_date product_category         product_name  \
# order_id
# 1001          CU-201 2020-01-15      Electronics  Wireless Headphones
# 1002          CU-156 2020-01-16         Clothing          Men's Jeans
# 1003          CU-342 2020-01-18   Home & Kitchen              Blender
# 1004          CU-201 2020-02-02      Electronics           Smartphone
# 1005          CU-499 2020-02-05            Books   Python Programming
#
#           quantity  unit_price  total_price  discount_pct  \
# order_id
# 1001             1       89.99        89.99          0.05
# 1002             2       45.50        91.00          0.15
# 1003             1       32.75        32.75          0.00
# 1004             1      699.00       699.00          0.10
# 1005             3       24.99        74.97          0.20
#
#           unit_price_after_discount  total_price_after_discount  \
# order_id
# 1001                          85.49                       85.49
# ...

# %%
pd.DataFrame({"Mean price before discount": [df["total_price"].mean()], "Mean price after discount": [df["total_price_after_discount"].mean()]}, index=["Mean price"])
# Out:
#             Mean price before discount  Mean price after discount
# Mean price                     167.908                   154.3442

# %%
LE=df["total_price_after_discount"]*47.77
df.insert(9, "total_price_after_discount_in_LE", LE)

# %%
df.head()
# Out:
#          customer_id order_date product_category         product_name  \
# order_id
# 1001          CU-201 2020-01-15      Electronics  Wireless Headphones
# 1002          CU-156 2020-01-16         Clothing          Men's Jeans
# 1003          CU-342 2020-01-18   Home & Kitchen              Blender
# 1004          CU-201 2020-02-02      Electronics           Smartphone
# 1005          CU-499 2020-02-05            Books   Python Programming
#
#           quantity  unit_price  total_price  discount_pct  \
# order_id
# 1001             1       89.99        89.99          0.05
# 1002             2       45.50        91.00          0.15
# 1003             1       32.75        32.75          0.00
# 1004             1      699.00       699.00          0.10
# 1005             3       24.99        74.97          0.20
#
#           unit_price_after_discount  total_price_after_discount_in_LE  \
# order_id
# 1001                          85.49                         4083.8573
# ...

# %%
pd.DataFrame((df.loc[df['customer_segment'] == "Premium", ["country"]].value_counts().astype(np.int8)))
# Out:
#          count
# country
# USA         20
